# %% [markdown]
# ## Optimization in Electricity Markets
#
# This notebook will closely follow examples described and given in Optimization Models in Electricity Markets by Anthony Papavasiliou. The purpose of this notebook is to gain experience and show how to use industry examples of this. The framework chosen for this is pyomo since it is the most well known free framework that can be used by anybody. It isn't ideal for matrices or vector constraints so they are not natively supported but still useful.

# %%
# Import the necessary libraries
import pyomo.environ as pyo

from src import GeneratorCommitment

# %% [markdown]
# ### Example 2.3:
#
# Consider the following Example where we are focussed on three generators with the goal of producing a demand of 200 MW at a minimum cost.
# Each generator can either be turned on or off. Let $p_i$ denote the power produced by generator $i$ and $\mu_i$ be a binary variable that indicates whether a generator has been activated or not.
#
# \begin{array}{lccc}
# \hline \text { Generator } & \text { Activation cost (\$) } & \text { Marg. cost (\$/MWh) } & \text { Capacity (MW) } \\
# \hline \text { Cheap } & 500 & 0 & 20 \\
# \text { Moderate } & 1000 & 10 & 100 \\
# \text { Expensive } & 2000 & 80 & 100 \\
# \hline
# \end{array}
#
#
# The minimization problem can be expressed as
#
# \[
# \begin{aligned}
# & \min_{p,u}\; 500u_1 + 1000u_2 + 10p_2 + 2000u_3 + 80p_3 \\
# & \text{s.t.}\; 0 \le p_1 \le 20u_1 \\
# & \phantom{\text{s.t.}}\; 0 \le p_2 \le 100u_2 \\
# & \phantom{\text{s.t.}}\; 0 \le p_3 \le 100u_3 \\
# & \lambda:\; p_1 + p_2 + p_3 = 200 \\
# & u_i \in \{0,1\}
# \end{aligned}
# \]

# %%
# Create or instantiate the model object
model = pyo.ConcreteModel()

# we want to see the lagrangian values
model.dual = pyo.Suffix(direction=pyo.Suffix.IMPORT_EXPORT)

# define the model types: Binary variables
model.u1 = pyo.Var(domain=pyo.Binary)
model.u2 = pyo.Var(domain=pyo.Binary)
model.u3 = pyo.Var(domain=pyo.Binary)

# define the model types: nonnegative real numbers
model.p1 = pyo.Var(domain = pyo.NonNegativeReals)
model.p2 = pyo.Var(domain = pyo.NonNegativeReals)
model.p3 = pyo.Var(domain = pyo.NonNegativeReals)

# define the objective function
model.obj = pyo.Objective(expr = 500 * model.u1 +1000 * model.u2 + 10* model.p2 + 2000 * model.u3 + 80 * model.p3,
                          sense = pyo.minimize)


# Capacity upper bounds: 0 ≤ p_i ≤ cap_i·u_i (lower bound already enforced by NonNegativeReals)
model.capacity_u1 = pyo.Constraint(expr=model.p1 <= 20 * model.u1)
model.capacity_u2 = pyo.Constraint(expr=model.p2 <= 100 * model.u2)
model.capacity_u3 = pyo.Constraint(expr=model.p3 <= 100 * model.u3)

# Demand balance: p1 + p2 + p3 = 200 MW
model.demand_balance = pyo.Constraint(expr=model.p1 + model.p2 + model.p3 == 200)

# %% [markdown]
# This has setup the basic of the model so far but know we need to decide how we want to solve this and pyomo is a framework that can work with differnt solver using the SolverFactory arguement. Lets check which solvers are available for pyomo using the following command in the termninal: pyomo help --solvers
#
# This gives the complete list of solvers. Now we need to set this based on what we have installed. Note that MOSEK and CPLEX need to be installed separately so we won't use them for now. But very useful

# %%
# list of differnet solvers 
candidates = ["glpk","highs","cbc","cplex","ipopt","mindtpy","mosek"]
print("Solver availability:\n")
for name in candidates:
    available = pyo.SolverFactory(name).available(False)
    print(f"{name:<7} -> {available}")
# Out:
# Solver availability:
#
# glpk    -> True
# highs   -> True
# cbc     -> True
# cplex   -> False
# ipopt   -> True
# mindtpy -> True
# mosek   -> False

# %% [markdown]
# Now we can set the solver. Choosing cbc for this case! But what if we want to set the type of solver that CBC uses?

# %%
solver = pyo.SolverFactory('cbc')
result = solver.solve(model, tee=True)

print(result)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug  2 2025
#
# command line - C:\Users\Gurjivan\miniforge3\envs\opt_env\Library\bin\cbc.exe -printingOptions all -import C:\Users\Gurjivan\AppData\Local\Temp\tmp6pxv8fs6.pyomo.lp -stat=1 -solve -solu C:\Users\Gurjivan\AppData\Local\Temp\tmp6pxv8fs6.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
# Presolve 4 (0) rows, 6 (0) columns and 9 (0) elements
# Statistics for presolved model
# Original problem has 3 integers (3 of which binary)
# ==== 1 zero objective 6 different
# 1 variables have objective of 0
# 1 variables have objective of 10
# 1 variables have objective of 80
# 1 variables have objective of 500
# 1 variables have objective of 1000
# 1 variables have objective of 2000
# ==== absolute objective values 6 different
# 1 variables have objective of 0
# 1 variables have objective of 10
# 1 variables have objective of 80
# 1 variables have objective of 500
# 1 variables have objective of 1000
# 1 variables have objective of 2000
# ==== for integers 0 zero objective 3 different
# 1 variables have objective of 500
# 1 variables have objective of 1000
# 1 variables have objective of 2000
# ==== for integers absolute objective values 3 different
# 1 variables have objective of 500
# 1 variables have objective of 1000
# 1 variables have objective of 2000
# ===== end objective counts
#
#
# Problem has 4 rows, 6 columns (5 with objective) and 9 elements
# There are 3 singletons with objective
# Column breakdown:
# 3 of type 0.0->inf, 0 of type 0.0->up, 0 of type lo->inf,
# 0 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 3 of type 0.0->1.0
# Row breakdown:
# 0 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 1 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 3 of type L 0.0, 0 of type L 1.0,
# 0 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 10500 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 3 columns (1 integer (1 of which binary)) and 3 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 10900
# Cbc0038I Relaxing continuous gives 10900
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 1 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.21 seconds)
# Cbc0038I After 0.21 seconds - Feasibility pump exiting with objective of 10900 - took 0.00 seconds
# Cbc0012I Integer solution of 10900 found by feasibility pump after 0 iterations and 0 nodes (0.21 seconds)
# Cbc0001I Search completed - best objective 10900, took 0 iterations and 0 nodes (0.21 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 10900 to 10900
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10900.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.21
# Time (Wallclock seconds):       0.21
#
# Total time (CPU seconds):       0.22   (Wallclock seconds):       0.22
#
#
# Problem:
# - Name: unknown
#   Lower bound: 10900.0
#   Upper bound: 10900.0
#   Number of objectives: 1
#   Number of constraints: 4
#   Number of variables: 6
#   Number of binary variables: 3
#   Number of integer variables: 3
#   Number of nonzeros: 5
#   Sense: minimize
# Solver:
# - Status: ok
#   User time: -1.0
#   System time: 0.22
#   Wallclock time: 0.22
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#     Black box:
#       Number of iterations: 0
#   Error rc: 0
#   Time: 0.4359011650085449
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
print(f"Total Dollars: ${pyo.value(model.obj):,.2f}")
print(f"Generator 1 is set: {model.u1.value:.0f} with power of {model.p1.value:.1f} MW/h")
print(f"Generator 2 is set: {model.u2.value:.0f} with power of {model.p2.value:.1f} MW/h")
print(f"Generator 3 is set: {model.u3.value:.0f} with power of {model.p3.value:.1f} MW/h")
# Out:
# Total Dollars: $10,900.00
# Generator 1 is set: 1 with power of 20.0 MW/h
# Generator 2 is set: 1 with power of 100.0 MW/h
# Generator 3 is set: 1 with power of 80.0 MW/h

# %%
for c in model.component_objects(pyo.Constraint, active=True):
    for idx in c:
        print(c[idx], model.dual[c[idx]])
# Out:
# capacity_u1 -80.0
# capacity_u2 -70.0
# capacity_u3 0.0
# demand_balance 80.0

# %% [markdown]
# In this case scenario it means that by relaxing generator 1 max constrain by 1 MW would raise cost by $80.
#
# We got an ideal result here but in terms of longevity we have issues since what if we want to run this for multiple generators, more constraints, but the same objective function in general, we will be copy and pasting this exact code alot. This is why while the above format is technically valid it is more ideal to run this in a more functional form.

# %%
print("="*60)
print("GENERATOR COMMITMENT")
print("="*60)

generators = ['Gen1', 'Gen2', 'Gen3']
gen_data = {
    'Gen1': {'fixed_cost': 500, 'var_cost': 0, 'capacity': 20},
    'Gen2': {'fixed_cost': 1000, 'var_cost': 10, 'capacity': 100},
    'Gen3': {'fixed_cost': 2000, 'var_cost': 80, 'capacity': 100},
}

uc = GeneratorCommitment(generators, gen_data, demand=200)
uc.build().solve(tee=False)
uc.print_results()
# Out:
# ============================================================
# GENERATOR COMMITMENT
# ============================================================
#
# Problem:
# - Name: unknown
#   Lower bound: 10900.0
#   Upper bound: 10900.0
#   Number of objectives: 1
#   Number of constraints: 4
#   Number of variables: 6
#   Number of binary variables: 3
#   Number of integer variables: 3
#   Number of nonzeros: 5
#   Sense: minimize
# Solver:
# - Status: ok
#   User time: -1.0
#   System time: 0.02
#   Wallclock time: 0.02
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#     Black box:
#       Number of iterations: 0
#   Error rc: 0
#   Time: 0.05351543426513672
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
#
# Total Cost: $10,900.00
#
# Generator Status:
#   Gen1: on=1, power=20.0/20 MW
#   Gen2: on=1, power=100.0/100 MW
#   Gen3: on=1, power=80.0/100 MW
#
# Constraint Duals (Shadow Prices):
#   capacity_constraint[Gen1] = -80.0
#   capacity_constraint[Gen2] = -70.0
#   capacity_constraint[Gen3] = 0.0
#   demand_constraint[None] = 80.0
